# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
df = pd.read_excel("Demo.xlsx")

# %%
df
# Out:
#     Roll no            Name of Student  \
# 0         1          RAVAL MEET MAHESH
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# ..      ...                        ...
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
# 72       73       JAGTAP HARISH YUVRAJ
# 73       74               ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                          1131  80.785714          29
# 1                                          1107  79.071429          29
# 2                                           995  71.071429          27
# 3                                          1077  76.928571          28
# 4                                          1064  76.000000          28
# ..                                          ...        ...         ...
# 69                                          725  51.785714          13
# 70                                          756  54.000000           4
# 71                                          608  43.428571          26
# 72                                          542  38.714286          18
# 73                                          646  46.142857          14
#
#           %.1  50% maks of Previous Year SPPU Result  \
# 0   96.666667                              44.000000
# 1   96.666667                              42.000000
# 2   90.000000                              41.000000
# 3   93.333333                              43.000000
# 4   93.333333                              42.000000
# ..        ...                                    ...
# 69  43.333333                              25.892857
# 70  13.333333                              27.000000
# 71  86.666667                              21.714286
# 72  60.000000                              19.357143
# 73  46.666667                              23.071429
#
#     50% Marks of Unit Test 1  Total 100%
# 0                         41   85.000000
# 1                         41   83.000000
# 2                         41   82.000000
# 3                         39   82.000000
# 4                         38   80.000000
# ..                       ...         ...
# 69                        29   54.892857
# 70                        25   52.000000
# 71                        29   50.714286
# 72                        31   50.357143
# 73                        22   45.071429
#
# [74 rows x 9 columns]

# %%
df.head()
# Out:
#    Roll no            Name of Student  \
# 0        1          RAVAL MEET MAHESH
# 1        2      HUMBE BHAKTI RAJENDRA
# 2        3  MARATHE SANSKRUTI JAGDISH
# 3        4      THAKARE MRUNALI VINOD
# 4        5    BHONGALE OMKAR MADHUKAR
#
#    Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                         1131  80.785714          29
# 1                                         1107  79.071429          29
# 2                                          995  71.071429          27
# 3                                         1077  76.928571          28
# 4                                         1064  76.000000          28
#
#          %.1  50% maks of Previous Year SPPU Result  50% Marks of Unit Test 1  \
# 0  96.666667                                   44.0                        41
# 1  96.666667                                   42.0                        41
# 2  90.000000                                   41.0                        41
# 3  93.333333                                   43.0                        39
# 4  93.333333                                   42.0                        38
#
#    Total 100%
# 0        85.0
# 1        83.0
# 2        82.0
# 3        82.0
# 4        80.0

# %%
df.tail()
# Out:
#     Roll no        Name of Student  \
# 69       70  KUNWAR ABHIJEET SINGH
# 70       71         TUPE OM KISHOR
# 71       72   DARWEY RUDRA GUNWANT
# 72       73   JAGTAP HARISH YUVRAJ
# 73       74           ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 69                                          725  51.785714          13
# 70                                          756  54.000000           4
# 71                                          608  43.428571          26
# 72                                          542  38.714286          18
# 73                                          646  46.142857          14
#
#           %.1  50% maks of Previous Year SPPU Result  \
# 69  43.333333                              25.892857
# 70  13.333333                              27.000000
# 71  86.666667                              21.714286
# 72  60.000000                              19.357143
# 73  46.666667                              23.071429
#
#     50% Marks of Unit Test 1  Total 100%
# 69                        29   54.892857
# 70                        25   52.000000
# 71                        29   50.714286
# 72                        31   50.357143
# 73                        22   45.071429

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 9 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Roll no                                      74 non-null     int64
#  1   Name of Student                              74 non-null     object
#  2   Previous Year SPPU Total Marks out of  1400  74 non-null     int64
#  3   %                                            74 non-null     float64
#  4   UT 1 Marks                                   74 non-null     int64
#  5   %.1                                          74 non-null     float64
#  6   50% maks of Previous Year SPPU Result        74 non-null     float64
#  7   50% Marks of Unit Test 1                     74 non-null     int64
#  8   Total 100%                                   74 non-null     float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 5.3+ KB

# %%
df.describe()
# Out:
#          Roll no  Previous Year SPPU Total Marks out of  1400          %  \
# count  74.000000                                    74.000000  74.000000
# mean   37.500000                                   951.567568  67.969112
# std    21.505813                                   141.310024  10.093573
# min     1.000000                                   542.000000  38.714286
# 25%    19.250000                                   880.000000  62.857143
# 50%    37.500000                                   970.000000  69.285714
# 75%    55.750000                                  1059.750000  75.696429
# max    74.000000                                  1203.000000  85.928571
#
#        UT 1 Marks        %.1  50% maks of Previous Year SPPU Result  \
# count   74.000000  74.000000                              74.000000
# mean    23.432432  78.108108                              34.394788
# std      4.935422  16.451405                               5.595003
# min      4.000000  13.333333                              19.357143
# 25%     21.000000  70.000000                              31.428571
# 50%     24.000000  80.000000                              34.642857
# 75%     27.000000  90.000000                              37.848214
# max     29.000000  96.666667                              45.000000
#
#        50% Marks of Unit Test 1  Total 100%
# count                 74.000000   74.000000
# mean                  33.635135   68.029923
# std                    4.961701    8.241659
# min                   21.000000   45.071429
# 25%                   31.000000   63.910714
# 50%                   34.000000   68.892857
# 75%                   37.000000   73.303571
# max                   41.000000   85.000000

# %%
df.isnull().sum()
# Out:
# Roll no                                        0
# Name of Student                                0
# Previous Year SPPU Total Marks out of  1400    0
# %                                              0
# UT 1 Marks                                     0
# %.1                                            0
# 50% maks of Previous Year SPPU Result          0
# 50% Marks of Unit Test 1                       0
# Total 100%                                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Roll no                                          int64
# Name of Student                                 object
# Previous Year SPPU Total Marks out of  1400      int64
# %                                              float64
# UT 1 Marks                                       int64
# %.1                                            float64
# 50% maks of Previous Year SPPU Result          float64
# 50% Marks of Unit Test 1                         int64
# Total 100%                                     float64
# dtype: object

# %%
numeric_cols = df.select_dtypes(include=["int64","float64"]).columns

# %%
numeric_cols
# Out:
# Index(['Roll no', 'Previous Year SPPU Total Marks out of  1400', '%',
#        'UT 1 Marks', '%.1', '50% maks of Previous Year SPPU Result',
#        '50% Marks of Unit Test 1', 'Total 100%'],
#       dtype='object')

# %%
df[numeric_cols].isnull().sum()
# Out:
# Roll no                                        0
# Previous Year SPPU Total Marks out of  1400    0
# %                                              0
# UT 1 Marks                                     0
# %.1                                            0
# 50% maks of Previous Year SPPU Result          0
# 50% Marks of Unit Test 1                       0
# Total 100%                                     0
# dtype: int64

# %%
X = df[numeric_cols]

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
X_scaled = min_max_scaler.fit_transform(X)

# %%
df_normalized = pd.DataFrame(X_scaled,columns=numeric_cols)

# %%
df[numeric_cols] = df_normalized

# %%
df.head()
# Out:
#     Roll no            Name of Student  \
# 0  0.000000          RAVAL MEET MAHESH
# 1  0.013699      HUMBE BHAKTI RAJENDRA
# 2  0.027397  MARATHE SANSKRUTI JAGDISH
# 3  0.041096      THAKARE MRUNALI VINOD
# 4  0.054795    BHONGALE OMKAR MADHUKAR
#
#    Previous Year SPPU Total Marks out of  1400         %  UT 1 Marks   %.1  \
# 0                                     0.891074  0.891074        1.00  1.00
# 1                                     0.854766  0.854766        1.00  1.00
# 2                                     0.685325  0.685325        0.92  0.92
# 3                                     0.809380  0.809380        0.96  0.96
# 4                                     0.789713  0.789713        0.96  0.96
#
#    50% maks of Previous Year SPPU Result  50% Marks of Unit Test 1  Total 100%
# 0                               0.961003                      1.00    1.000000
# 1                               0.883008                      1.00    0.949911
# 2                               0.844011                      1.00    0.924866
# 3                               0.922006                      0.90    0.924866
# 4                               0.883008                      0.85    0.874776

# %%
df.describe()
# Out:
#        Roll no  Previous Year SPPU Total Marks out of  1400          %  \
# count  74.0000                                    74.000000  74.000000
# mean    0.5000                                     0.619618   0.619618
# std     0.2946                                     0.213782   0.213782
# min     0.0000                                     0.000000   0.000000
# 25%     0.2500                                     0.511346   0.511346
# 50%     0.5000                                     0.647504   0.647504
# 75%     0.7500                                     0.783283   0.783283
# max     1.0000                                     1.000000   1.000000
#
#        UT 1 Marks        %.1  50% maks of Previous Year SPPU Result  \
# count   74.000000  74.000000                              74.000000
# mean     0.777297   0.777297                               0.586426
# std      0.197417   0.197417                               0.218190
# min      0.000000   0.000000                               0.000000
# 25%      0.680000   0.680000                               0.470752
# 50%      0.800000   0.800000                               0.596100
# 75%      0.920000   0.920000                               0.721100
# max      1.000000   1.000000                               1.000000
#
#        50% Marks of Unit Test 1  Total 100%
# count                 74.000000   74.000000
# mean                   0.631757    0.574989
# std                    0.248085    0.206410
# min                    0.000000    0.000000
# 25%                    0.500000    0.471825
# 50%                    0.650000    0.596601
# 75%                    0.800000    0.707066
# max                    1.000000    1.000000

# %%
df[numeric_cols].boxplot()
plt.show()
